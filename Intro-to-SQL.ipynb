# %% [markdown]
# # Introduction to postgres SQL
#
# This notebook is meant to be a short introduction to relational database queries using SQL.
#
# Note that you will need to load the database first (see that notebook for more information).
#
# Make sure that you change <USERNAME> below to your own username!

# %%
# %reload_ext sql

##Connect to the database
#%sql postgresql://postgres@localhost/ensembl


#%sql postgresql://postgres:postpost@localhost:5433/ensembl
# %sql postgresql://<USERNAME>@localhost/ensembl

# %% [markdown]
# # SELECTing from a table in the database
#
# All SQL queries have the following form:
#
# ```
# SELECT *columns*  <- required
# FROM *table*      <- required
# WHERE *criteria*  <- this clause is optional
# ```
#
# The very first thing we can do is return all the columns from a query using `*`. But remember, we need a `FROM` clause as well to make our query complete.

# %%
# %sql SELECT * FROM gene LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 20 rows affected.
# [('ENSG00000198888          ', 1, 4262, 3307, 'MT', 'MT-ND1'),
#  ('ENSG00000198763          ', 1, 5511, 4470, 'MT', 'MT-ND2'),
#  ('ENSG00000198804          ', 1, 7445, 5904, 'MT', 'MT-CO1'),
#  ('ENSG00000198712          ', 1, 8269, 7586, 'MT', 'MT-CO2'),
#  ('ENSG00000228253          ', 1, 8572, 8366, 'MT', 'MT-ATP8'),
#  ('ENSG00000198899          ', 1, 9207, 8527, 'MT', 'MT-ATP6'),
#  ('ENSG00000198938          ', 1, 9990, 9207, 'MT', 'MT-CO3'),
#  ('ENSG00000198840          ', 1, 10404, 10059, 'MT', 'MT-ND3'),
#  ('ENSG00000212907          ', 1, 10766, 10470, 'MT', 'MT-ND4L'),
#  ('ENSG00000198886          ', 1, 12137, 10760, 'MT', 'MT-ND4'),
#  ('ENSG00000198786          ', 1, 14148, 12337, 'MT', 'MT-ND5'),
#  ('ENSG00000198695          ', -1, 14673, 14149, 'MT', 'MT-ND6'),
#  ('ENSG00000198727          ', 1, 15887, 14747, 'MT', 'MT-CYB'),
#  ('ENSG00000277953          ', 1, 54131896, 54115536, 'CHR_HSCHR19LRC_LRC_T_CTG3_1', 'AC012314.16'),
#  ('ENSG00000277836          ', 1, 1271271, 1270984, 'KI270728.1', 'AC141272.1'),
#  ('ENSG00000278817          ', 1, 137392, 131494, 'KI270734.1', 'AC007325.4'),
#  ('ENSG00000257215          ', 1, 31217512, 31215489, 'CHR_HSCHR6_MHC_MANN_CTG1', 'CR847794.2'),
#  ('ENSG00000204805          ', 1, 61863200, 61861625, '9', 'AL391987.2'),
#  ('ENSG00000282035          ', -1, 11846845, 11844908, 'CHR_HSCHR3_1_CTG1', 'AC090958.4'),
#  ('ENSG00000273896          ', 1, 54195141, 54190866, 'CHR_HSCHR19LRC_LRC_T_CTG3_1', 'TSEN34')]

# %% [markdown]
# # WHERE
#
# WHERE is an optional clause, but it lets us add filtering criteria to your query. We use the LIMIT clause to only show the first 20 lines of our table.

# %%
# %sql SELECT * FROM gene WHERE chromosome = '14' LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 20 rows affected.
# [('ENSG00000100505          ', -1, 51096061, 50975262, '14', 'TRIM9'),
#  ('ENSG00000139921          ', 1, 51257655, 51240162, '14', 'TMX1'),
#  ('ENSG00000139926          ', 1, 51730727, 51489100, '14', 'FRMD6'),
#  ('ENSG00000172717          ', 1, 67228550, 67189393, '14', 'FAM71D'),
#  ('ENSG00000100749          ', 1, 96931722, 96797382, '14', 'VRK1'),
#  ('ENSG00000186469          ', 1, 51979342, 51826195, '14', 'GNG2'),
#  ('ENSG00000072415          ', 1, 67336061, 67241342, '14', 'MPP5'),
#  ('ENSG00000100554          ', -1, 67360265, 67294371, '14', 'ATP6V1D'),
#  ('ENSG00000134001          ', 1, 67386516, 67360151, '14', 'EIF2S1'),
#  ('ENSG00000087302          ', 1, 52010694, 51989514, '14', 'RTRAF'),
#  ('ENSG00000087303          ', -1, 52069228, 52004803, '14', 'NID2'),
#  ('ENSG00000176605          ', 1, 98717766, 98711613, '14', 'C14orf177'),
#  ('ENSG00000127152          ', -1, 99272197, 99169287, '14', 'BCL11B'),
#  ('ENSG00000168229          ', 1, 52276724, 52267698, '14', 'PTGDR'),
#  ('ENSG00000125384          ', 1, 52328598, 52314305, '14', 'PTGER2'),
#  ('ENSG00000087301          ', -1, 52552522, 52430596, '14', 'TXNDC16'),
#  ('ENSG00000183576          ', -1, 99480889, 99397748, '14', 'SETD3'),
#  ('ENSG00000180998          ', 1, 52637713, 52552836, '14', 'GPR137C'),
#  ('ENSG00000197930          ', -1, 52695900, 52639915, '14', 'ERO1A'),
#  ('ENSG00000100558          ', -1, 67412167, 67386984, '14', 'PLEK2')]

# %% [markdown]
# # Boolean Operations
#
# We can chain criteria together by using the `AND`/`OR` boolean operations.

# %%
# %%sql
# SELECT * FROM gene WHERE gene_end < 100000 AND chromosome = '10'
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 1 rows affected.
# [('ENSG00000261456          ', -1, 74163, 46892, '10', 'TUBB8')]

# %% [markdown]
# ## Think about it
#
# Should an AND query be *larger* or *smaller* than an OR query?

# %%
# %%sql
# SELECT * FROM gene WHERE gene_end < 100000 OR chromosome = '10'

# %% [markdown]
# # SELECTING columns
#
# You can select individual columns of each table using the SELECT statement.
#
# Note that we have to put our chromosome (`14`) in quotes since the datatype of the column is character.

# %%
# %%sql
# SELECT ensembl_gene_id, gene_start, chromosome
# FROM gene
# WHERE chromosome = '14'
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 19 rows affected.
# [('ENSG00000211890          ', 105583731, '14'),
#  ('ENSG00000211890          ', 105583731, '14'),
#  ('ENSG00000211891          ', 105597691, '14'),
#  ('ENSG00000211891          ', 105597691, '14'),
#  ('ENSG00000211892          ', 105620506, '14'),
#  ('ENSG00000211892          ', 105620506, '14'),
#  ('ENSG00000211893          ', 105639559, '14'),
#  ('ENSG00000211893          ', 105639559, '14'),
#  ('ENSG00000211895          ', 105703995, '14'),
#  ('ENSG00000211895          ', 105703995, '14'),
#  ('ENSG00000211896          ', 105736343, '14'),
#  ('ENSG00000211896          ', 105736343, '14'),
#  ('ENSG00000211896          ', 105736343, '14'),
#  ('ENSG00000211897          ', 105764503, '14'),
#  ('ENSG00000211897          ', 105764503, '14'),
#  ('ENSG00000211898          ', 105836765, '14'),
#  ('ENSG00000211898          ', 105836765, '14'),
#  ('ENSG00000211899          ', 105851705, '14'),
#  ('ENSG00000211899          ', 105851705, '14')]

# %% [markdown]
# # Your Turn
#
# Write a SELECT statement that returns everything from the `gene` table if gene_symbol = `FGFR2`

# %%
#Room for your answer here

# %sql
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 'Connected: postgres@ensembl'

# %% [markdown]
# # Aliases using AS
#
# One useful trick we can use are *aliases*. This becomes more important as we join tables together, since it:
#
# 1. Saves us typing
# 2. Makes our query more clear and specific.
#
# You can see that `ensembl_gene_id` might be in multiple tables. Postgres gets confused if we don't.
#
# In general, you can use an alias *before* you define it in the query, which is confusing. You just need to define it somewhere (usually in the FROM clause).
#
# When you refer to a column, it is best to preface it with the *alias* so your query is exact.

# %%
# %%sql
# SELECT g.ensembl_gene_id, g.gene_start, g.chromosome
#     FROM gene as g
#     WHERE chromosome = '14' LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 10 rows affected.
# [('ENSG00000100505          ', 50975262, '14'),
#  ('ENSG00000139921          ', 51240162, '14'),
#  ('ENSG00000139926          ', 51489100, '14'),
#  ('ENSG00000172717          ', 67189393, '14'),
#  ('ENSG00000100749          ', 96797382, '14'),
#  ('ENSG00000186469          ', 51826195, '14'),
#  ('ENSG00000072415          ', 67241342, '14'),
#  ('ENSG00000100554          ', 67294371, '14'),
#  ('ENSG00000134001          ', 67360151, '14'),
#  ('ENSG00000087302          ', 51989514, '14')]

# %% [markdown]
# We can also rename our columns using AS:

# %%
# %%sql
# SELECT ensembl_gene_id as ensembl, gene_start, chromosome FROM gene
# WHERE chromosome = '14' LIMIT 20;

# %% [markdown]
# # Aggregating using COUNT
#
# The COUNT verb in SQL lets us count things. If we use COUNT(ensembl_gene_id), it will count the number of

# %%
# %sql SELECT COUNT(ensembl_transcript_id) FROM transcript;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 1 rows affected.
# [(168617,)]

# %%
# %sql SELECT COUNT(DISTINCT ensembl_gene_id) FROM gene2transcript;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 1 rows affected.
# [(22799,)]

# %% [markdown]
# # GROUP BY
#
# GROUP BY is extremely useful if we want to produce a table of counts. Note that to produce a table with counts, we need to return both `chromosome` and `COUNT(chromosome)`.

# %%
# %sql SELECT chromosome, COUNT(chromosome) FROM gene GROUP BY chromosome;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 357 rows affected.
# [('CHR_HSCHR1_5_CTG32_1', 3),
#  ('13', 321),
#  ('CHR_HSCHR17_3_CTG1', 8),
#  ('CHR_HSCHR21_6_CTG1_1', 1),
#  ('CHR_HSCHR1_ALT2_1_CTG32_1', 7),
#  ('CHR_HSCHR1_1_CTG3', 7),
#  ('CHR_HSCHR19KIR_FH08_A_HAP_CTG3_1', 9),
#  ('CHR_HSCHR22_1_CTG7', 17),
#  ('Y', 48),
#  ('CHR_HSCHR19LRC_LRC_S_CTG3_1', 19),
#  ('CHR_HSCHR11_1_CTG6', 7),
#  ('CHR_HG1298_PATCH', 1),
#  ('18', 267),
#  ('2', 1246),
#  ('CHR_HSCHR22_1_CTG4', 2),
#  ('CHR_HSCHR21_4_CTG1_1', 4),
#  ('CHR_HSCHR6_MHC_DBB_CTG1', 151),
#  ('CHR_HSCHR17_2_CTG1', 1),
#  ('CHR_HSCHR12_4_CTG2', 2),
#  ('CHR_HSCHR22_7_CTG1', 2),
#  ('CHR_HG26_PATCH', 17),
#  ('CHR_HSCHR19KIR_T7526_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR13_1_CTG5', 2),
#  ('CHR_HSCHR19KIR_HG2396_CTG3_1', 4),
#  ('CHR_HG1277_PATCH', 3),
#  ('CHR_HSCHR19KIR_0019-4656-A_CTG3_1', 6),
#  ('CHR_HSCHR3_1_CTG2_1', 1),
#  ('CHR_HSCHR17_5_CTG4', 6),
#  ('CHR_HSCHR19_3_CTG3_1', 3),
#  ('CHR_HG2510_PATCH', 2),
#  ('CHR_HSCHR19KIR_FH05_B_HAP_CTG3_1', 14),
#  ('CHR_HSCHR19LRC_COX1_CTG3_1', 36),
#  ('CHR_HG2198_PATCH', 6),
#  ('CHR_HSCHR2_4_CTG1', 2),
#  ('CHR_HSCHR17_10_CTG4', 9),
#  ('CHR_HSCHR6_MHC_MCF_CTG1', 152),
#  ('CHR_HSCHR6_MHC_MANN_CTG1', 132),
#  ('CHR_HSCHR1_3_CTG32_1', 3),
#  ('CHR_HSCHR11_1_CTG5', 4),
#  ('CHR_HSCHR19LRC_LRC_I_CTG3_1', 21),
#  ('CHR_HSCHR1_2_CTG32_1', 7),
#  ('CHR_HG2095_PATCH', 5),
#  ('CHR_HSCHR11_2_CTG1_1', 8),
#  ('CHR_HSCHR6_MHC_SSTO_CTG1', 134),
#  ('CHR_HSCHR8_5_CTG7', 2),
#  ('CHR_HSCHR8_8_CTG1', 3),
#  ('CHR_HG2114_PATCH', 8),
#  ('CHR_HSCHR7_1_CTG7', 1),
#  ('10', 730),
#  ('CHR_HSCHR2_3_CTG1', 1),
#  ('CHR_HSCHR16_1_CTG1', 23),
#  ('CHR_HG1398_PATCH', 5),
#  ('CHR_HSCHR7_2_CTG4_4', 4),
#  ('CHR_HSCHR3_7_CTG3', 2),
#  ('CHR_HSCHR8_7_CTG7', 1),
#  ('CHR_HSCHR12_3_CTG2', 22),
#  ('CHR_HSCHR6_1_CTG4', 2),
#  ('CHR_HSCHR19KIR_CA01-TA01_2_CTG3_1', 6),
#  ('CHR_HSCHR4_1_CTG12', 3),
#  ('CHR_HSCHR9_1_CTG6', 1),
#  ('CHR_HSCHR18_ALT2_CTG2_1', 2),
#  ('CHR_HSCHR14_1_CTG1', 2),
#  ('CHR_HSCHR9_1_CTG5', 2),
#  ('CHR_HSCHR1_1_CTG32_1', 1),
#  ('CHR_HG28_PATCH', 6),
#  ('CHR_HSCHR8_1_CTG1', 1),
#  ('CHR_HSCHR10_1_CTG2', 3),
#  ('CHR_HG2046_PATCH', 15),
#  ('CHR_HSCHR20_1_CTG2', 2),
#  ('CHR_HSCHRX_2_CTG12', 1),
#  ('CHR_HG2419_PATCH', 12),
#  ('CHR_HSCHR17_2_CTG2', 4),
#  ('22', 443),
#  ('CHR_HG1342_HG2282_PATCH', 19),
#  ('CHR_HSCHR18_5_CTG1_1', 1),
#  ('CHR_HSCHR5_8_CTG1', 7),
#  ('CHR_HSCHR15_2_CTG8', 1),
#  ('CHR_HG2058_PATCH', 1),
#  ('CHR_HSCHR15_3_CTG3', 1),
#  ('CHR_HG2191_PATCH', 2),
#  ('KI270731.1', 1),
#  ('CHR_HSCHR3_9_CTG2_1', 2),
#  ('CHR_HG2030_PATCH', 14),
#  ('CHR_HSCHR18_2_CTG2_1', 2),
#  ('CHR_HSCHR15_1_CTG1', 3),
#  ('CHR_HG986_PATCH', 1),
#  ('CHR_HSCHR1_1_CTG31', 4),
#  ('CHR_HSCHR5_1_CTG1_1', 8),
#  ('KI270711.1', 1),
#  ('14', 612),
#  ('CHR_HSCHR10_1_CTG4', 1),
#  ('CHR_HSCHR15_1_CTG3', 3),
#  ('6', 1047),
#  ('CHR_HSCHR22_6_CTG1', 2),
#  ('CHR_HSCHR19KIR_FH13_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR16_5_CTG1', 3),
#  ('CHR_HSCHR22_1_CTG5', 2),
#  ('CHR_HG2263_PATCH', 1),
#  ('CHR_HG1815_PATCH', 5),
#  ('CHR_HSCHR4_6_CTG12', 2),
#  ('CHR_HSCHR8_3_CTG1', 9),
#  ('CHR_HSCHR22_4_CTG1', 3),
#  ('CHR_HG708_PATCH', 9),
#  ('CHR_HG2291_PATCH', 1),
#  ('CHR_HG2023_PATCH', 14),
#  ('CHR_HSCHR12_3_CTG2_1', 2),
#  ('CHR_HSCHR11_2_CTG1', 1),
#  ('CHR_HSCHR19KIR_LUCE_BDEL_HAP_CTG3_1', 10),
#  ('CHR_HG1362_PATCH', 5),
#  ('CHR_HSCHR16_3_CTG1', 9),
#  ('CHR_HG1832_PATCH', 2),
#  ('CHR_HSCHR19KIR_RSH_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR19KIR_FH05_A_HAP_CTG3_1', 9),
#  ('CHR_HG699_PATCH', 1),
#  ('CHR_HSCHR19_2_CTG3_1', 2),
#  ('KI270713.1', 2),
#  ('CHR_HSCHR17_3_CTG4', 1),
#  ('CHR_HG2213_PATCH', 1),
#  ('GL000195.1', 2),
#  ('CHR_HSCHR15_1_CTG8', 4),
#  ('CHR_HSCHR2_3_CTG15', 4),
#  ('CHR_HSCHR2_2_CTG7_2', 1),
#  ('CHR_HSCHR5_3_CTG1', 3),
#  ('CHR_HSCHR19KIR_502960008-2_CTG3_1', 6),
#  ('CHR_HSCHR12_2_CTG2', 15),
#  ('CHR_HSCHR16_4_CTG3_1', 2),
#  ('CHR_HSCHR5_3_CTG5', 1),
#  ('CHR_HG2499_PATCH', 3),
#  ('CHR_HG2247_PATCH', 2),
#  ('CHR_HSCHR19_4_CTG2', 1),
#  ('CHR_HG1395_PATCH', 5),
#  ('CHR_HSCHR11_1_CTG7', 6),
#  ('CHR_HSCHR19KIR_RSH_BA2_HAP_CTG3_1', 8),
#  ('CHR_HSCHR6_1_CTG8', 2),
#  ('5', 885),
#  ('CHR_HG2285_HG106_HG2252_PATCH', 3),
#  ('CHR_HG1485_PATCH', 1),
#  ('CHR_HG2121_PATCH', 3),
#  ('CHR_HG721_PATCH', 1),
#  ('CHR_HSCHR3_4_CTG3', 2),
#  ('CHR_HSCHR22_1_CTG3', 3),
#  ('CHR_HG76_PATCH', 70),
#  ('CHR_HSCHR19KIR_HG2394_CTG3_1', 7),
#  ('GL000205.2', 1),
#  ('CHR_HSCHR19KIR_7191059-2_CTG3_1', 7),
#  ('GL000213.1', 1),
#  ('CHR_HSCHR18_3_CTG2_1', 1),
#  ('CHR_HSCHR4_9_CTG12', 5),
#  ('CHR_HSCHR17_4_CTG4', 22),
#  ('CHR_HSCHR12_5_CTG2', 1),
#  ('CHR_HSCHR2_8_CTG7_2', 3),
#  ('CHR_HG2232_PATCH', 4),
#  ('CHR_HSCHR3_2_CTG3', 1),
#  ('CHR_HSCHR1_4_CTG3', 6),
#  ('CHR_HSCHR19KIR_G085_BA1_HAP_CTG3_1', 6),
#  ('CHR_HSCHR10_1_CTG1', 1),
#  ('CHR_HG1_PATCH', 36),
#  ('CHR_HG2021_PATCH', 8),
#  ('CHR_HSCHR19KIR_G085_A_HAP_CTG3_1', 6),
#  ('CHR_HSCHR3_1_CTG1', 2),
#  ('CHR_HSCHR19KIR_0010-5217-AB_CTG3_1', 4),
#  ('CHR_HSCHRX_1_CTG3', 1),
#  ('CHR_HSCHR17_9_CTG4', 1),
#  ('CHR_HSCHR17_7_CTG4', 52),
#  ('CHR_HSCHR7_3_CTG4_4', 22),
#  ('CHR_HSCHR19KIR_G248_BA2_HAP_CTG3_1', 8),
#  ('CHR_HSCHR17_1_CTG5', 14),
#  ('CHR_HSCHR17_2_CTG5', 11),
#  ('CHR_HG2266_PATCH', 6),
#  ('8', 682),
#  ('CHR_HSCHR21_5_CTG2', 3),
#  ('CHR_HSCHR7_1_CTG6', 4),
#  ('CHR_HSCHR17_6_CTG4', 6),
#  ('CHR_HG2471_PATCH', 3),
#  ('CHR_HSCHR17_1_CTG9', 3),
#  ('KI270726.1', 2),
#  ('CHR_HG2511_PATCH', 1),
#  ('CHR_HSCHR19KIR_CA04_CTG3_1', 3),
#  ('CHR_HG1708_PATCH', 1),
#  ('CHR_HSCHR19KIR_GRC212_BA1_HAP_CTG3_1', 8),
#  ('CHR_HSCHR19KIR_HG2393_CTG3_1', 8),
#  ('CHR_HSCHR19_5_CTG2', 6),
#  ('CHR_HSCHR19KIR_T7526_BDEL_HAP_CTG3_1', 9),
#  ('CHR_HSCHR12_1_CTG1', 2),
#  ('CHR_HSCHR2_1_CTG1', 2),
#  ('CHR_HSCHR19KIR_FH15_A_HAP_CTG3_1', 6),
#  ('CHR_HG2217_PATCH', 7),
#  ('CHR_HSCHR19KIR_7191059-1_CTG3_1', 6),
#  ('CHR_HSCHR19KIR_LUCE_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR1_3_CTG31', 2),
#  ('CHR_HG109_PATCH', 16),
#  ('CHR_HSCHR6_MHC_APD_CTG1', 81),
#  ('CHR_HSCHR6_1_CTG5', 2),
#  ('4', 751),
#  ('9', 779),
#  ('CHR_HSCHR8_5_CTG1', 1),
#  ('CHR_HG2063_PATCH', 1),
#  ('GL000009.2', 1),
#  ('CHR_HG926_PATCH', 19),
#  ('MT', 13),
#  ('CHR_HSCHR1_8_CTG3', 4),
#  ('CHR_HG2235_PATCH', 2),
#  ('CHR_HSCHR1_6_CTG3', 1),
#  ('CHR_HSCHR19KIR_0019-4656-B_CTG3_1', 10),
#  ('CHR_HSCHR1_2_CTG31', 6),
#  ('11', 1309),
#  ('CHR_HG2509_PATCH', 2),
#  ('CHR_HG1309_PATCH', 2),
#  ('CHR_HSCHR19KIR_FH06_BA1_HAP_CTG3_1', 9),
#  ('CHR_HSCHR16_5_CTG3_1', 4),
#  ('CHR_HSCHR19KIR_G248_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR19KIR_FH13_BA2_HAP_CTG3_1', 9),
#  ('CHR_HSCHR16_CTG2', 2),
#  ('CHR_HSCHR14_8_CTG1', 1),
#  ('CHR_HG2088_PATCH', 2),
#  ('12', 1031),
#  ('CHR_HSCHR12_8_CTG2_1', 1),
#  ('7', 918),
#  ('15', 597),
#  ('CHR_HG1311_PATCH', 2),
#  ('CHR_HG126_PATCH', 1),
#  ('CHR_HSCHR19KIR_FH08_BAX_HAP_CTG3_1', 8),
#  ('CHR_HG107_PATCH', 3),
#  ('CHR_HSCHR15_2_CTG3', 2),
#  ('CHR_HSCHR19KIR_GRC212_AB_HAP_CTG3_1', 9),
#  ('CHR_HSCHR5_2_CTG5', 1),
#  ('CHR_HSCHR3_8_CTG3', 2),
#  ('CHR_HSCHR3_2_CTG2_1', 2),
#  ('CHR_HG2512_PATCH', 1),
#  ('CHR_HSCHR8_2_CTG7', 1),
#  ('CHR_HSCHR19_4_CTG3_1', 42),
#  ('CHR_HSCHR2_1_CTG5', 1),
#  ('CHR_HG2087_PATCH', 13),
#  ('CHR_HSCHR19LRC_COX2_CTG3_1', 29),
#  ('CHR_HSCHR4_12_CTG12', 1),
#  ('CHR_HSCHR18_2_CTG2', 1),
#  ('CHR_HSCHR19KIR_502960008-1_CTG3_1', 6),
#  ('CHR_HSCHR1_2_CTG3', 8),
#  ('X', 851),
#  ('21', 232),
#  ('CHR_HSCHR19KIR_CA01-TB01_CTG3_1', 10),
#  ('CHR_HSCHR19_2_CTG2', 2),
#  ('CHR_HSCHR19KIR_FH06_A_HAP_CTG3_1', 8),
#  ('17', 1184),
#  ('CHR_HSCHR4_11_CTG12', 13),
#  ('GL000218.1', 1),
#  ('CHR_HSCHR3_6_CTG3', 1),
#  ('CHR_HSCHR15_4_CTG8', 19),
#  ('CHR_HSCHR7_2_CTG6', 13),
#  ('CHR_HSCHR11_1_CTG8', 12),
#  ('CHR_HSCHR22_3_CTG1', 4),
#  ('3', 1076),
#  ('CHR_HG2104_PATCH', 1),
#  ('CHR_HSCHR17_1_CTG1', 3),
#  ('CHR_HSCHR15_6_CTG8', 9),
#  ('CHR_HG2115_PATCH', 2),
#  ('CHR_HG2066_PATCH', 12),
#  ('CHR_HSCHR9_1_CTG3', 1),
#  ('CHR_HSCHR7_1_CTG1', 1),
#  ('CHR_HSCHR8_4_CTG1', 1),
#  ('CHR_HSCHR3_1_CTG3', 2),
#  ('CHR_HSCHR5_5_CTG1', 2),
#  ('CHR_HSCHR7_3_CTG6', 1),
#  ('CHR_HG30_PATCH', 12),
#  ('CHR_HSCHR22_1_CTG2', 1),
#  ('CHR_HSCHR19LRC_LRC_T_CTG3_1', 21),
#  ('CHR_HG2002_PATCH', 6),
#  ('CHR_HSCHR17_1_CTG2', 8),
#  ('CHR_HSCHR12_1_CTG2_1', 1),
#  ('CHR_HSCHR15_3_CTG8', 2),
#  ('CHR_HSCHR8_4_CTG7', 3),
#  ('CHR_HSCHR16_2_CTG3_1', 2),
#  ('CHR_HSCHR8_7_CTG1', 2),
#  ('CHR_HG439_PATCH', 7),
#  ('KI270721.1', 1),
#  ('GL000194.1', 2),
#  ('CHR_HG2072_PATCH', 2),
#  ('CHR_HSCHR7_2_CTG1', 1),
#  ('CHR_HSCHR22_2_CTG1', 3),
#  ('19', 1471),
#  ('CHR_HSCHR12_5_CTG2_1', 1),
#  ('20', 545),
#  ('CHR_HSCHR22_1_CTG1', 3),
#  ('CHR_HSCHR19KIR_FH15_B_HAP_CTG3_1', 12),
#  ('CHR_HSCHR4_1_CTG4', 1),
#  ('CHR_HSCHR19KIR_ABC08_AB_HAP_T_P_CTG3_1', 6),
#  ('CHR_HSCHR11_2_CTG8', 2),
#  ('CHR_HSCHR11_1_CTG1_2', 6),
#  ('CHR_HSCHR3_6_CTG2_1', 3),
#  ('KI270734.1', 3),
#  ('GL000219.1', 1),
#  ('CHR_HSCHR19_3_CTG2', 2),
#  ('CHR_HSCHR3_5_CTG1', 1),
#  ('CHR_HSCHR8_3_CTG7', 15),
#  ('CHR_HSCHR19LRC_LRC_J_CTG3_1', 21),
#  ('CHR_HG1320_PATCH', 3),
#  ('KI270728.1', 6),
#  ('CHR_HSCHR14_7_CTG1', 23),
#  ('CHR_HSCHR9_1_CTG2', 1),
#  ('CHR_HSCHR5_6_CTG1', 3),
#  ('CHR_HSCHR2_1_CTG7_2', 4),
#  ('CHR_HSCHR19KIR_CA01-TA01_1_CTG3_1', 6),
#  ('CHR_HSCHR15_5_CTG8', 7),
#  ('CHR_HSCHR1_5_CTG3', 10),
#  ('CHR_HG2246_HG2248_HG2276_PATCH', 3),
#  ('CHR_HSCHR6_MHC_COX_CTG1', 163),
#  ('CHR_HSCHR1_4_CTG31', 1),
#  ('CHR_HSCHR3_5_CTG3', 2),
#  ('CHR_HG142_HG150_NOVEL_TEST', 8),
#  ('CHR_HSCHR2_6_CTG7_2', 5),
#  ('CHR_HSCHR19LRC_PGF2_CTG3_1', 29),
#  ('CHR_HSCHR20_1_CTG4', 1),
#  ('CHR_HSCHR22_5_CTG1', 2),
#  ('CHR_HSCHR4_1_CTG9', 5),
#  ('CHR_HSCHR13_1_CTG1', 2),
#  ('CHR_HSCHRX_2_CTG3', 1),
#  ('CHR_HSCHR16_1_CTG3_1', 2),
#  ('CHR_HSCHR11_1_CTG3_1', 5),
#  ('CHR_HSCHR19_1_CTG3_1', 2),
#  ('CHR_HSCHR17_1_CTG4', 8),
#  ('CHR_HSCHR5_4_CTG1', 2),
#  ('CHR_HSCHR20_1_CTG3', 5),
#  ('CHR_HG1524_PATCH', 2),
#  ('CHR_HSCHR19KIR_ABC08_A1_HAP_CTG3_1', 9),
#  ('CHR_HSCHR19_1_CTG2', 3),
#  ('CHR_HSCHR19KIR_RP5_B_HAP_CTG3_1', 10),
#  ('CHR_HSCHR19KIR_CA01-TB04_CTG3_1', 12),
#  ('CHR_HG2236_PATCH', 1),
#  ('CHR_HSCHR19LRC_PGF1_CTG3_1', 40),
#  ('CHR_HSCHR3_3_CTG3', 2),
#  ('CHR_HG2365_PATCH', 47),
#  ('CHR_HSCHR7_1_CTG4_4', 2),
#  ('1', 2049),
#  ('CHR_HG2513_PATCH', 2),
#  ('CHR_HG2525_PATCH', 2),
#  ('CHR_HSCHR8_9_CTG1', 4),
#  ('CHR_HG2111_PATCH', 4),
#  ('CHR_HSCHR6_MHC_QBL_CTG1', 153),
#  ('CHR_HSCHR21_3_CTG1_1', 2),
#  ('CHR_HG151_NOVEL_TEST', 3),
#  ('CHR_HSCHR5_2_CTG1_1', 16),
#  ('CHR_HG2288_HG2289_PATCH', 2),
#  ('CHR_HSCHR16_4_CTG1', 1),
#  ('CHR_HSCHR18_1_CTG1_1', 1),
#  ('CHR_HSCHR14_2_CTG1', 2),
#  ('CHR_HSCHR22_8_CTG1', 3),
#  ('CHR_HSCHR17_3_CTG2', 3),
#  ('CHR_HG2334_PATCH', 3),
#  ('KI270727.1', 4),
#  ('CHR_HSCHR6_8_CTG1', 2),
#  ('CHR_HG2047_PATCH', 1),
#  ('CHR_HSCHR19KIR_ABC08_AB_HAP_C_P_CTG3_1', 5),
#  ('CHR_HSCHR11_3_CTG1', 2),
#  ('CHR_HG545_PATCH', 1),
#  ('16', 852),
#  ('CHR_HSCHR12_6_CTG2_1', 2),
#  ('CHR_HG2057_PATCH', 4)]

# %% [markdown]
# # ORDER BY
#
# That's great and everything, but that doesn't answer the question of which chromosome has the largest number of mapped genes.
#
# By adding an `ORDER BY` clause followed by a `DESC`, we can sort our result table.

# %%
# %%sql
#     SELECT chromosome, COUNT(chromosome) as count
#         FROM gene
#         GROUP BY chromosome
#         ORDER BY count DESC;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 357 rows affected.
# [('1', 2049),
#  ('19', 1471),
#  ('11', 1309),
#  ('2', 1246),
#  ('17', 1184),
#  ('3', 1076),
#  ('6', 1047),
#  ('12', 1031),
#  ('7', 918),
#  ('5', 885),
#  ('16', 852),
#  ('X', 851),
#  ('9', 779),
#  ('4', 751),
#  ('10', 730),
#  ('8', 682),
#  ('14', 612),
#  ('15', 597),
#  ('20', 545),
#  ('22', 443),
#  ('13', 321),
#  ('18', 267),
#  ('21', 232),
#  ('CHR_HSCHR6_MHC_COX_CTG1', 163),
#  ('CHR_HSCHR6_MHC_QBL_CTG1', 153),
#  ('CHR_HSCHR6_MHC_MCF_CTG1', 152),
#  ('CHR_HSCHR6_MHC_DBB_CTG1', 151),
#  ('CHR_HSCHR6_MHC_SSTO_CTG1', 134),
#  ('CHR_HSCHR6_MHC_MANN_CTG1', 132),
#  ('CHR_HSCHR6_MHC_APD_CTG1', 81),
#  ('CHR_HG76_PATCH', 70),
#  ('CHR_HSCHR17_7_CTG4', 52),
#  ('Y', 48),
#  ('CHR_HG2365_PATCH', 47),
#  ('CHR_HSCHR19_4_CTG3_1', 42),
#  ('CHR_HSCHR19LRC_PGF1_CTG3_1', 40),
#  ('CHR_HSCHR19LRC_COX1_CTG3_1', 36),
#  ('CHR_HG1_PATCH', 36),
#  ('CHR_HSCHR19LRC_PGF2_CTG3_1', 29),
#  ('CHR_HSCHR19LRC_COX2_CTG3_1', 29),
#  ('CHR_HSCHR14_7_CTG1', 23),
#  ('CHR_HSCHR16_1_CTG1', 23),
#  ('CHR_HSCHR12_3_CTG2', 22),
#  ('CHR_HSCHR17_4_CTG4', 22),
#  ('CHR_HSCHR7_3_CTG4_4', 22),
#  ('CHR_HSCHR19LRC_LRC_I_CTG3_1', 21),
#  ('CHR_HSCHR19LRC_LRC_J_CTG3_1', 21),
#  ('CHR_HSCHR19LRC_LRC_T_CTG3_1', 21),
#  ('CHR_HSCHR19LRC_LRC_S_CTG3_1', 19),
#  ('CHR_HG1342_HG2282_PATCH', 19),
#  ('CHR_HSCHR15_4_CTG8', 19),
#  ('CHR_HG926_PATCH', 19),
#  ('CHR_HSCHR22_1_CTG7', 17),
#  ('CHR_HG26_PATCH', 17),
#  ('CHR_HSCHR5_2_CTG1_1', 16),
#  ('CHR_HG109_PATCH', 16),
#  ('CHR_HSCHR12_2_CTG2', 15),
#  ('CHR_HG2046_PATCH', 15),
#  ('CHR_HSCHR8_3_CTG7', 15),
#  ('CHR_HSCHR19KIR_FH05_B_HAP_CTG3_1', 14),
#  ('CHR_HSCHR17_1_CTG5', 14),
#  ('CHR_HG2030_PATCH', 14),
#  ('CHR_HG2023_PATCH', 14),
#  ('CHR_HG2087_PATCH', 13),
#  ('CHR_HSCHR4_11_CTG12', 13),
#  ('CHR_HSCHR7_2_CTG6', 13),
#  ('MT', 13),
#  ('CHR_HG2066_PATCH', 12),
#  ('CHR_HG2419_PATCH', 12),
#  ('CHR_HSCHR19KIR_CA01-TB04_CTG3_1', 12),
#  ('CHR_HG30_PATCH', 12),
#  ('CHR_HSCHR19KIR_FH15_B_HAP_CTG3_1', 12),
#  ('CHR_HSCHR11_1_CTG8', 12),
#  ('CHR_HSCHR17_2_CTG5', 11),
#  ('CHR_HSCHR19KIR_CA01-TB01_CTG3_1', 10),
#  ('CHR_HSCHR1_5_CTG3', 10),
#  ('CHR_HSCHR19KIR_0019-4656-B_CTG3_1', 10),
#  ('CHR_HSCHR19KIR_RP5_B_HAP_CTG3_1', 10),
#  ('CHR_HSCHR19KIR_LUCE_BDEL_HAP_CTG3_1', 10),
#  ('CHR_HSCHR19KIR_FH06_BA1_HAP_CTG3_1', 9),
#  ('CHR_HSCHR19KIR_FH13_BA2_HAP_CTG3_1', 9),
#  ('CHR_HSCHR19KIR_GRC212_AB_HAP_CTG3_1', 9),
#  ('CHR_HSCHR15_6_CTG8', 9),
#  ('CHR_HSCHR19KIR_ABC08_A1_HAP_CTG3_1', 9),
#  ('CHR_HSCHR8_3_CTG1', 9),
#  ('CHR_HG708_PATCH', 9),
#  ('CHR_HSCHR16_3_CTG1', 9),
#  ('CHR_HSCHR19KIR_FH05_A_HAP_CTG3_1', 9),
#  ('CHR_HSCHR19KIR_T7526_BDEL_HAP_CTG3_1', 9),
#  ('CHR_HSCHR19KIR_FH08_A_HAP_CTG3_1', 9),
#  ('CHR_HSCHR17_10_CTG4', 9),
#  ('CHR_HSCHR19KIR_G248_BA2_HAP_CTG3_1', 8),
#  ('CHR_HG142_HG150_NOVEL_TEST', 8),
#  ('CHR_HSCHR5_1_CTG1_1', 8),
#  ('CHR_HG2114_PATCH', 8),
#  ('CHR_HSCHR11_2_CTG1_1', 8),
#  ('CHR_HG2021_PATCH', 8),
#  ('CHR_HSCHR19KIR_GRC212_BA1_HAP_CTG3_1', 8),
#  ('CHR_HSCHR19KIR_HG2393_CTG3_1', 8),
#  ('CHR_HSCHR17_3_CTG1', 8),
#  ('CHR_HSCHR1_2_CTG3', 8),
#  ('CHR_HSCHR17_1_CTG2', 8),
#  ('CHR_HSCHR17_1_CTG4', 8),
#  ('CHR_HSCHR19KIR_RSH_BA2_HAP_CTG3_1', 8),
#  ('CHR_HSCHR19KIR_FH06_A_HAP_CTG3_1', 8),
#  ('CHR_HSCHR19KIR_FH08_BAX_HAP_CTG3_1', 8),
#  ('CHR_HSCHR19KIR_T7526_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR19KIR_G248_A_HAP_CTG3_1', 7),
#  ('CHR_HG2217_PATCH', 7),
#  ('CHR_HSCHR19KIR_LUCE_A_HAP_CTG3_1', 7),
#  ('CHR_HG439_PATCH', 7),
#  ('CHR_HSCHR11_1_CTG6', 7),
#  ('CHR_HSCHR5_8_CTG1', 7),
#  ('CHR_HSCHR1_2_CTG32_1', 7),
#  ('CHR_HSCHR19KIR_FH13_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR19KIR_HG2394_CTG3_1', 7),
#  ('CHR_HSCHR15_5_CTG8', 7),
#  ('CHR_HSCHR19KIR_7191059-2_CTG3_1', 7),
#  ('CHR_HSCHR19KIR_RSH_A_HAP_CTG3_1', 7),
#  ('CHR_HSCHR1_1_CTG3', 7),
#  ('CHR_HSCHR1_ALT2_1_CTG32_1', 7),
#  ('CHR_HSCHR17_5_CTG4', 6),
#  ('CHR_HSCHR19KIR_7191059-1_CTG3_1', 6),
#  ('CHR_HG2002_PATCH', 6),
#  ('CHR_HSCHR11_1_CTG7', 6),
#  ('CHR_HSCHR19KIR_FH15_A_HAP_CTG3_1', 6),
#  ('CHR_HSCHR17_6_CTG4', 6),
#  ('CHR_HSCHR19KIR_CA01-TA01_2_CTG3_1', 6),
#  ('CHR_HG2198_PATCH', 6),
#  ('CHR_HG28_PATCH', 6),
#  ('CHR_HSCHR19KIR_502960008-1_CTG3_1', 6),
#  ('CHR_HG2266_PATCH', 6),
#  ('CHR_HSCHR19KIR_CA01-TA01_1_CTG3_1', 6),
#  ('CHR_HSCHR1_2_CTG31', 6),
#  ('CHR_HSCHR19_5_CTG2', 6),
#  ('CHR_HSCHR1_4_CTG3', 6),
#  ('CHR_HSCHR19KIR_G085_BA1_HAP_CTG3_1', 6),
#  ('KI270728.1', 6),
#  ('CHR_HSCHR19KIR_G085_A_HAP_CTG3_1', 6),
#  ('CHR_HSCHR19KIR_502960008-2_CTG3_1', 6),
#  ('CHR_HSCHR11_1_CTG1_2', 6),
#  ('CHR_HSCHR19KIR_ABC08_AB_HAP_T_P_CTG3_1', 6),
#  ('CHR_HSCHR19KIR_0019-4656-A_CTG3_1', 6),
#  ('CHR_HSCHR2_6_CTG7_2', 5),
#  ('CHR_HG1398_PATCH', 5),
#  ('CHR_HG1362_PATCH', 5),
#  ('CHR_HG1815_PATCH', 5),
#  ('CHR_HG2095_PATCH', 5),
#  ('CHR_HSCHR4_1_CTG9', 5),
#  ('CHR_HSCHR20_1_CTG3', 5),
#  ('CHR_HSCHR11_1_CTG3_1', 5),
#  ('CHR_HSCHR19KIR_ABC08_AB_HAP_C_P_CTG3_1', 5),
#  ('CHR_HG1395_PATCH', 5),
#  ('CHR_HSCHR4_9_CTG12', 5),
#  ('CHR_HSCHR19KIR_HG2396_CTG3_1', 4),
#  ('CHR_HSCHR15_1_CTG8', 4),
#  ('CHR_HSCHR22_3_CTG1', 4),
#  ('CHR_HG2111_PATCH', 4),
#  ('CHR_HSCHR17_2_CTG2', 4),
#  ('CHR_HSCHR7_1_CTG6', 4),
#  ('CHR_HSCHR7_2_CTG4_4', 4),
#  ('CHR_HSCHR11_1_CTG5', 4),
#  ('CHR_HSCHR19KIR_0010-5217-AB_CTG3_1', 4),
#  ('CHR_HSCHR2_1_CTG7_2', 4),
#  ('CHR_HSCHR16_5_CTG3_1', 4),
#  ('CHR_HG2232_PATCH', 4),
#  ('CHR_HSCHR1_1_CTG31', 4),
#  ('CHR_HSCHR2_3_CTG15', 4),
#  ('CHR_HSCHR8_9_CTG1', 4),
#  ('CHR_HG2057_PATCH', 4),
#  ('KI270727.1', 4),
#  ('CHR_HSCHR1_8_CTG3', 4),
#  ('CHR_HSCHR21_4_CTG1_1', 4),
#  ('CHR_HSCHR17_1_CTG1', 3),
#  ('CHR_HSCHR16_5_CTG1', 3),
#  ('CHR_HSCHR22_4_CTG1', 3),
#  ('CHR_HSCHR22_1_CTG1', 3),
#  ('CHR_HSCHR10_1_CTG2', 3),
#  ('CHR_HSCHR1_5_CTG32_1', 3),
#  ('CHR_HG151_NOVEL_TEST', 3),
#  ('CHR_HG1277_PATCH', 3),
#  ('CHR_HSCHR5_3_CTG1', 3),
#  ('CHR_HG2499_PATCH', 3),
#  ('CHR_HSCHR4_1_CTG12', 3),
#  ('CHR_HG2285_HG106_HG2252_PATCH', 3),
#  ('CHR_HG2246_HG2248_HG2276_PATCH', 3),
#  ('CHR_HG2121_PATCH', 3),
#  ('CHR_HSCHR22_8_CTG1', 3),
#  ('CHR_HSCHR19_3_CTG3_1', 3),
#  ('CHR_HSCHR22_1_CTG3', 3),
#  ('CHR_HSCHR5_6_CTG1', 3),
#  ('CHR_HSCHR2_8_CTG7_2', 3),
#  ('CHR_HSCHR17_3_CTG2', 3),
#  ('CHR_HG2334_PATCH', 3),
#  ('CHR_HG1320_PATCH', 3),
#  ('CHR_HSCHR8_8_CTG1', 3),
#  ('CHR_HSCHR15_1_CTG3', 3),
#  ('CHR_HSCHR21_5_CTG2', 3),
#  ('CHR_HG2471_PATCH', 3),
#  ('CHR_HSCHR17_1_CTG9', 3),
#  ('CHR_HSCHR19KIR_CA04_CTG3_1', 3),
#  ('KI270734.1', 3),
#  ('CHR_HSCHR1_3_CTG32_1', 3),
#  ('CHR_HSCHR8_4_CTG7', 3),
#  ('CHR_HSCHR22_2_CTG1', 3),
#  ('CHR_HSCHR3_6_CTG2_1', 3),
#  ('CHR_HG107_PATCH', 3),
#  ('CHR_HSCHR15_1_CTG1', 3),
#  ('CHR_HSCHR19_1_CTG2', 3),
#  ('CHR_HSCHR22_5_CTG1', 2),
#  ('CHR_HSCHR22_1_CTG4', 2),
#  ('CHR_HSCHR12_4_CTG2', 2),
#  ('CHR_HSCHR22_7_CTG1', 2),
#  ('CHR_HSCHR13_1_CTG5', 2),
#  ('CHR_HG2510_PATCH', 2),
#  ('CHR_HSCHR2_4_CTG1', 2),
#  ('CHR_HSCHR8_5_CTG7', 2),
#  ('CHR_HSCHR3_7_CTG3', 2),
#  ('CHR_HSCHR6_1_CTG4', 2),
#  ('CHR_HSCHR18_ALT2_CTG2_1', 2),
#  ('CHR_HSCHR14_1_CTG1', 2),
#  ('CHR_HSCHR9_1_CTG5', 2),
#  ('CHR_HSCHR20_1_CTG2', 2),
#  ('CHR_HG2191_PATCH', 2),
#  ('CHR_HSCHR3_9_CTG2_1', 2),
#  ('CHR_HSCHR18_2_CTG2_1', 2),
#  ('CHR_HSCHR22_6_CTG1', 2),
#  ('CHR_HSCHR22_1_CTG5', 2),
#  ('CHR_HSCHR4_6_CTG12', 2),
#  ('CHR_HSCHR12_3_CTG2_1', 2),
#  ('CHR_HG1832_PATCH', 2),
#  ('CHR_HSCHR19_2_CTG3_1', 2),
#  ('KI270713.1', 2),
#  ('GL000195.1', 2),
#  ('CHR_HSCHR16_4_CTG3_1', 2),
#  ('CHR_HG2247_PATCH', 2),
#  ('CHR_HSCHR6_1_CTG8', 2),
#  ('CHR_HSCHR3_4_CTG3', 2),
#  ('CHR_HSCHR3_1_CTG1', 2),
#  ('KI270726.1', 2),
#  ('CHR_HSCHR12_1_CTG1', 2),
#  ('CHR_HSCHR2_1_CTG1', 2),
#  ('CHR_HSCHR1_3_CTG31', 2),
#  ('CHR_HSCHR6_1_CTG5', 2),
#  ('CHR_HG2235_PATCH', 2),
#  ('CHR_HG2509_PATCH', 2),
#  ('CHR_HG1309_PATCH', 2),
#  ('CHR_HSCHR16_CTG2', 2),
#  ('CHR_HG2088_PATCH', 2),
#  ('CHR_HG1311_PATCH', 2),
#  ('CHR_HSCHR15_2_CTG3', 2),
#  ('CHR_HSCHR3_8_CTG3', 2),
#  ('CHR_HSCHR3_2_CTG2_1', 2),
#  ('CHR_HSCHR19_2_CTG2', 2),
#  ('CHR_HG2115_PATCH', 2),
#  ('CHR_HSCHR3_1_CTG3', 2),
#  ('CHR_HSCHR5_5_CTG1', 2),
#  ('CHR_HSCHR15_3_CTG8', 2),
#  ('CHR_HSCHR16_2_CTG3_1', 2),
#  ('CHR_HSCHR8_7_CTG1', 2),
#  ('GL000194.1', 2),
#  ('CHR_HG2072_PATCH', 2),
#  ('CHR_HSCHR11_2_CTG8', 2),
#  ('CHR_HSCHR19_3_CTG2', 2),
#  ('CHR_HSCHR3_5_CTG3', 2),
#  ('CHR_HSCHR13_1_CTG1', 2),
#  ('CHR_HSCHR16_1_CTG3_1', 2),
#  ('CHR_HSCHR19_1_CTG3_1', 2),
#  ('CHR_HSCHR5_4_CTG1', 2),
#  ('CHR_HG1524_PATCH', 2),
#  ('CHR_HSCHR3_3_CTG3', 2),
#  ('CHR_HSCHR7_1_CTG4_4', 2),
#  ('CHR_HG2513_PATCH', 2),
#  ('CHR_HG2525_PATCH', 2),
#  ('CHR_HSCHR21_3_CTG1_1', 2),
#  ('CHR_HG2288_HG2289_PATCH', 2),
#  ('CHR_HSCHR14_2_CTG1', 2),
#  ('CHR_HSCHR6_8_CTG1', 2),
#  ('CHR_HSCHR11_3_CTG1', 2),
#  ('CHR_HSCHR12_6_CTG2_1', 2),
#  ('CHR_HSCHR12_5_CTG2_1', 1),
#  ('CHR_HSCHR12_8_CTG2_1', 1),
#  ('CHR_HSCHR14_8_CTG1', 1),
#  ('CHR_HSCHR1_6_CTG3', 1),
#  ('CHR_HSCHR4_1_CTG4', 1),
#  ('GL000009.2', 1),
#  ('CHR_HSCHR1_1_CTG32_1', 1),
#  ('CHR_HG2063_PATCH', 1),
#  ('CHR_HSCHR8_5_CTG1', 1),
#  ('CHR_HG1708_PATCH', 1),
#  ('GL000219.1', 1),
#  ('CHR_HSCHR9_1_CTG6', 1),
#  ('CHR_HSCHR3_5_CTG1', 1),
#  ('CHR_HG2511_PATCH', 1),
#  ('CHR_HSCHR17_9_CTG4', 1),
#  ('CHR_HSCHRX_1_CTG3', 1),
#  ('CHR_HSCHR10_1_CTG1', 1),
#  ('CHR_HSCHR3_2_CTG3', 1),
#  ('CHR_HSCHR9_1_CTG2', 1),
#  ('CHR_HSCHR12_5_CTG2', 1),
#  ('CHR_HSCHR18_3_CTG2_1', 1),
#  ('GL000213.1', 1),
#  ('GL000205.2', 1),
#  ('CHR_HG721_PATCH', 1),
#  ('CHR_HG1485_PATCH', 1),
#  ('CHR_HSCHR19_4_CTG2', 1),
#  ('CHR_HSCHR1_4_CTG31', 1),
#  ('CHR_HSCHR21_6_CTG1_1', 1),
#  ('CHR_HSCHR5_3_CTG5', 1),
#  ('CHR_HSCHR2_2_CTG7_2', 1),
#  ('CHR_HG2213_PATCH', 1),
#  ('CHR_HSCHR20_1_CTG4', 1),
#  ('CHR_HSCHR17_3_CTG4', 1),
#  ('CHR_HG699_PATCH', 1),
#  ('CHR_HSCHR16_4_CTG1', 1),
#  ('CHR_HSCHRX_2_CTG3', 1),
#  ('CHR_HSCHR18_1_CTG1_1', 1),
#  ('CHR_HSCHR11_2_CTG1', 1),
#  ('CHR_HG545_PATCH', 1),
#  ('CHR_HG2291_PATCH', 1),
#  ('CHR_HSCHR8_7_CTG7', 1),
#  ('CHR_HG2263_PATCH', 1),
#  ('CHR_HSCHR2_3_CTG1', 1),
#  ('CHR_HSCHR10_1_CTG4', 1),
#  ('KI270711.1', 1),
#  ('CHR_HG986_PATCH', 1),
#  ('KI270731.1', 1),
#  ('CHR_HG2236_PATCH', 1),
#  ('CHR_HSCHR15_3_CTG3', 1),
#  ('CHR_HSCHR7_1_CTG7', 1),
#  ('CHR_HG2058_PATCH', 1),
#  ('CHR_HG2104_PATCH', 1),
#  ('CHR_HSCHR3_1_CTG2_1', 1),
#  ('CHR_HSCHR3_6_CTG3', 1),
#  ('CHR_HSCHR9_1_CTG3', 1),
#  ('CHR_HSCHR7_1_CTG1', 1),
#  ('CHR_HSCHR8_4_CTG1', 1),
#  ('CHR_HSCHR15_2_CTG8', 1),
#  ('CHR_HG1298_PATCH', 1),
#  ('CHR_HSCHR7_3_CTG6', 1),
#  ('GL000218.1', 1),
#  ('CHR_HSCHR22_1_CTG2', 1),
#  ('CHR_HSCHR18_2_CTG2', 1),
#  ('CHR_HSCHR4_12_CTG12', 1),
#  ('CHR_HSCHR2_1_CTG5', 1),
#  ('CHR_HSCHR12_1_CTG2_1', 1),
#  ('CHR_HG2047_PATCH', 1),
#  ('CHR_HSCHR8_2_CTG7', 1),
#  ('CHR_HSCHR18_5_CTG1_1', 1),
#  ('CHR_HSCHRX_2_CTG12', 1),
#  ('CHR_HG2512_PATCH', 1),
#  ('KI270721.1', 1),
#  ('CHR_HSCHR8_1_CTG1', 1),
#  ('CHR_HSCHR17_2_CTG1', 1),
#  ('CHR_HSCHR7_2_CTG1', 1),
#  ('CHR_HSCHR5_2_CTG5', 1),
#  ('CHR_HG126_PATCH', 1)]

# %% [markdown]
# # Your Turn
#
# How many genes are mapped to the `1` (+) strand and how many genes are mapped to the `-1` (-) strand?

# %%
#Room for your answer here
# %sql

# %% [markdown]
# # JOINing the Tables
#
# Of course, our `transcript` and `gene` tables aren't that useful by themselves. We need to integrate information in these tables to produce useful queries.
#
# We will use what are called JOINs on the data, to produce a table that has information about genes and their transcripts.

# %% [markdown]
# # The Different JOIN types
#
# I apologize for the different tables here. However, these figures took a long time to make and I don't have the time to make bioinformatics specific ones.
#
# - INNER JOIN
#
# Only retains the rows which are in common between the two joined tables.
#
# ![](docs/image/Slide3.JPG)
#
# - LEFT JOIN
#
# Retains everything in INNER JOIN, plus those rows in the LEFT table.
#
# ![](docs/image/Slide4.JPG)
#
# - RIGHT JOIN
#
# Retains everything in INNER JOIN, plus those rows in the LEFT table.
#
# - OUTER JOIN
#
# Retains ALL rows in both tables, regardless of whether there is matching criteria.

# %% [markdown]
# ## Quiz Yourself
#
# How many rows would there be in the results table above if we RIGHT JOINed instead?

# %% [markdown]
# # LEFT JOIN in action
#
# Now, let's try a `LEFT JOIN` on our data.

# %%
# %%sql
#     SELECT g.ensembl_gene_id,
#         g.gene_start,
#         g.gene_symbol,
#         t2g.ensembl_transcript_id
#     FROM gene AS g
#     LEFT JOIN gene2transcript AS t2g
#         ON g.ensembl_gene_id = t2g.ensembl_gene_id
#     LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 10 rows affected.
# [('ENSG00000198888          ', 3307, 'MT-ND1', 'ENST00000361390          '),
#  ('ENSG00000198763          ', 4470, 'MT-ND2', 'ENST00000361453          '),
#  ('ENSG00000198804          ', 5904, 'MT-CO1', 'ENST00000361624          '),
#  ('ENSG00000198712          ', 7586, 'MT-CO2', 'ENST00000361739          '),
#  ('ENSG00000228253          ', 8366, 'MT-ATP8', 'ENST00000361851          '),
#  ('ENSG00000198899          ', 8527, 'MT-ATP6', 'ENST00000361899          '),
#  ('ENSG00000198938          ', 9207, 'MT-CO3', 'ENST00000362079          '),
#  ('ENSG00000198840          ', 10059, 'MT-ND3', 'ENST00000361227          '),
#  ('ENSG00000212907          ', 10470, 'MT-ND4L', 'ENST00000361335          '),
#  ('ENSG00000198886          ', 10760, 'MT-ND4', 'ENST00000361381          ')]

# %% [markdown]
# You may recall that we have **three** tables: `gene`, `gene2transcript` and `transcript`. To join together `gene` and `transcript`, our `LEFT JOIN` has to include all three tables.
#
# We can do this by adding another `LEFT JOIN` clause to our query. Here we're adding in the `transcript` table by including the criteria `t2g.ensembl_transcript_id` = `t.ensembl_transcript_id`.

# %%
# %%sql
#     SELECT g.ensembl_gene_id, g.gene_start, g.gene_symbol, t.ensembl_transcript_id, t.transcript_start
#     FROM gene AS g
#     LEFT JOIN gene2transcript AS t2g
#         ON g.ensembl_gene_id = t2g.ensembl_gene_id
#     LEFT JOIN transcript as t
#         ON t2g.ensembl_transcript_id = t.ensembl_transcript_id
#     LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 10 rows affected.
# [('ENSG00000198786          ', 12337, 'MT-ND5', 'ENST00000361567          ', 12337),
#  ('ENSG00000278817          ', 131494, 'AC007325.4', 'ENST00000613204          ', 131494),
#  ('ENSG00000281022          ', 133338460, 'MED22', 'ENST00000631196          ', 133338460),
#  ('ENSG00000274053          ', 54643934, 'NCR1', 'ENST00000619679          ', 54643934),
#  ('ENSG00000273506          ', 54911759, 'NCR1', 'ENST00000619067          ', 54911759),
#  ('ENSG00000277667          ', 54160649, 'AC012314.14', 'ENST00000622368          ', 54160649),
#  ('ENSG00000277733          ', 54173854, 'MBOAT7', 'ENST00000612567          ', 54173854),
#  ('ENSG00000276017          ', 72411, 'AC007325.1', 'ENST00000617983          ', 72411),
#  ('ENSG00000280584          ', 133205277, 'OBP2B', 'ENST00000630166          ', 133205277),
#  ('ENSG00000143954          ', 79025686, 'REG3G', 'ENST00000498312          ', 79025748)]

# %% [markdown]
# # Use Case: Finding Overlapping Genes
#
# One query we might do is to find all of the overlapping genes in our database.
#
# That is, we want those genes where
#
# ```
# gene1.gene_symbol != gene2.gene_symbol
# gene1.chromosome = gene2.chromosome
# gene1.start > gene2.end and
# gene2.end < gene.1 start and
# ```
#
# How do we do this, since we only have 1 table? We need to do what is called a SELF JOIN.
#
# Basically, we make two aliases for our table, called `g1` and `g2`. Then we can join these two tables just like any other join. Here we use an `INNER JOIN`.

# %%
# %%sql
#     SELECT g1.gene_symbol AS gene1,
#         g2.gene_symbol AS gene2,
#         g1.gene_start as g1_start,
#         g2.gene_start as g2_start,
#         g1.gene_end as g1_end,
#         g2.gene_end as g1_end
#     FROM gene AS g1
#     INNER JOIN gene AS g2
#         ON g1.gene_symbol != g2.gene_symbol
#     WHERE g1.gene_start <= g2.gene_end
#         AND g1.gene_end >= g2.gene_start
#         AND g1.chromosome = g2.chromosome;

# %% [markdown]
# # Using EXPLAIN ANALYZE to find out why our query is slow
#
# Because we are joining and scanning many tables for a query, some of the more complicated ones may take a lot longer to run.
#
# If we add `EXPLAIN ANALYZE` to the beginning of our query, we will understand what tasks the Database Management System (DBMS) take the longest.

# %%
#Need to run this for demo purposes
# %%sql
    DROP INDEX IF EXISTS ChrStartEnd;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# Done.
# []

# %%
# %%sql
#     EXPLAIN ANALYZE
#     SELECT g1.gene_symbol AS gene1,
#         g2.gene_symbol AS gene2,
#         g1.gene_start as g1_start,
#         g2.gene_start as g2_start,
#         g1.gene_end as g1_end,
#         g2.gene_end as g1_end
#     FROM gene AS g1
#     INNER JOIN gene AS g2
#         ON g1.gene_symbol != g2.gene_symbol
#     WHERE g1.gene_start <= g2.gene_end
#         AND g1.gene_end >= g2.gene_start
#         AND g1.chromosome = g2.chromosome;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 10 rows affected.
# [('Hash Join  (cost=747.98..430934.97 rows=2357115 width=12) (actual time=24.184..8822.094 rows=10846 loops=1)',),
#  ('  Hash Cond: ((g1.chromosome)::text = (g2.chromosome)::text)',),
#  ('  Join Filter: (((g1.gene_symbol)::text <> (g2.gene_symbol)::text) AND (g1.gene_start <= g2.gene_end) AND (g1.gene_end >= g2.gene_start))',),
#  ('  Rows Removed by Join Filter: 21205785',),
#  ('  ->  Seq Scan on gene g1  (cost=0.00..462.99 rows=22799 width=19) (actual time=0.063..15.625 rows=22799 loops=1)',),
#  ('  ->  Hash  (cost=462.99..462.99 rows=22799 width=19) (actual time=23.785..23.785 rows=22799 loops=1)',),
#  ('        Buckets: 32768  Batches: 1  Memory Usage: 1443kB',),
#  ('        ->  Seq Scan on gene g2  (cost=0.00..462.99 rows=22799 width=19) (actual time=0.035..10.678 rows=22799 loops=1)',),
#  ('Planning Time: 3.032 ms',),
#  ('Execution Time: 8825.565 ms',)]

# %% [markdown]
# # Indexing: making a query faster
#
# Querying takes time, because we have to scan the whole table.
#
# However, if there is a column we query a lot, we can create a **index** for it. This index allows us to query the table faster.
#
# Much like the other data structures we use in Python, an *index* takes the form of a B-Tree, which allows for much more rapid searching of the data.
#
# Why don't we index everything? Well, indexes take a lot of disk space. So we are better off picking and choosing which columns we want to index. This is based on what kinds of queries and searches that are the most commonly done on a table.
#
# There are data engineers whose job it is to tune the database to make queries run faster. Don't worry too much if this is confusing right now. Just know who you're going to talk with when you need a database query to run lightning fast.

# %%
# %%sql
# CREATE INDEX ChrStartEnd on gene(chromosome, gene_start, gene_end)
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# Done.
# []

# %% [markdown]
# Now try running the query again with `EXPLAIN ANALYZE`. How much faster was it on your machine?

# %%
# %%sql
#     EXPLAIN ANALYZE
#     SELECT g1.gene_symbol AS gene1,
#         g2.gene_symbol AS gene2,
#         g1.gene_start as g1_start,
#         g2.gene_start as g2_start,
#         g1.gene_end as g1_end,
#         g2.gene_end as g1_end
#     FROM gene AS g1
#     INNER JOIN gene AS g2
#         ON g1.gene_symbol != g2.gene_symbol
#     WHERE g1.gene_start <= g2.gene_end
#         AND g1.gene_end >= g2.gene_start
#         AND g1.chromosome = g2.chromosome;
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 8 rows affected.
# [('Nested Loop  (cost=0.29..17921.28 rows=2357115 width=12) (actual time=0.266..2351.437 rows=10846 loops=1)',),
#  ('  ->  Seq Scan on gene g1  (cost=0.00..462.99 rows=22799 width=19) (actual time=0.069..6.443 rows=22799 loops=1)',),
#  ('  ->  Index Scan using chrstartend on gene g2  (cost=0.29..0.70 rows=7 width=19) (actual time=0.101..0.101 rows=0 loops=22799)',),
#  ('        Index Cond: (((chromosome)::text = (g1.chromosome)::text) AND (gene_start <= g1.gene_end) AND (gene_end >= g1.gene_start))',),
#  ('        Filter: ((g1.gene_symbol)::text <> (gene_symbol)::text)',),
#  ('        Rows Removed by Filter: 1',),
#  ('Planning Time: 5.373 ms',),
#  ('Execution Time: 2353.030 ms',)]

# %% [markdown]
# # Indexing and Primary Keys
#
# In our next session, we will be learning some useful terminology for our database:
# - Primary Keys, which uniquely identify a row in a table
# - Foreign Keys, which refer to a key in another table

# %% [markdown]
# # Useful to know: Subqueries
#
# This has been a lot of SQL to throw at you! So I'm making this last section optional.
#
# Sometimes it's useful to break up complicated queries into subqueries. Basically any query that returns a table can be used in a FROM statement, but you must create an alias for the subquery.

# %%
# %%sql
# SELECT ensembl_gene_id, gene_symbol
#     FROM
#     (SELECT * FROM gene WHERE chromosome = '1') AS subquery
#     WHERE subquery.gene_start >= 1000000
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 2040 rows affected.
# [('ENSG00000116996          ', 'ZP4'),
#  ('ENSG00000270188          ', 'MTRNR2L11'),
#  ('ENSG00000203685          ', 'STUM'),
#  ('ENSG00000143772          ', 'ITPKB'),
#  ('ENSG00000120370          ', 'GORAB'),
#  ('ENSG00000117480          ', 'FAAH'),
#  ('ENSG00000157978          ', 'LDLRAP1'),
#  ('ENSG00000143801          ', 'PSEN2'),
#  ('ENSG00000260238          ', 'PMF1-BGLAP'),
#  ('ENSG00000242252          ', 'BGLAP'),
#  ('ENSG00000160781          ', 'PAQR6'),
#  ('ENSG00000160783          ', 'PMF1'),
#  ('ENSG00000143669          ', 'LYST'),
#  ('ENSG00000168710          ', 'AHCYL1'),
#  ('ENSG00000158715          ', 'SLC45A3'),
#  ('ENSG00000069275          ', 'NUCKS1'),
#  ('ENSG00000117643          ', 'MAN1C1'),
#  ('ENSG00000143379          ', 'SETDB1'),
#  ('ENSG00000116132          ', 'PRRX1'),
#  ('ENSG00000197587          ', 'DMBX1'),
#  ('ENSG00000092978          ', 'GPATCH2'),
#  ('ENSG00000116478          ', 'HDAC1'),
#  ('ENSG00000116752          ', 'BCAS2'),
#  ('ENSG00000117280          ', 'RAB29'),
#  ('ENSG00000143418          ', 'CERS2'),
#  ('ENSG00000133019          ', 'CHRM3'),
#  ('ENSG00000117859          ', 'OSBPL9'),
#  ('ENSG00000143256          ', 'PFDN2'),
#  ('ENSG00000131591          ', 'C1orf159'),
#  ('ENSG00000143398          ', 'PIP5K1A'),
#  ('ENSG00000158796          ', 'DEDD'),
#  ('ENSG00000187801          ', 'ZFP69B'),
#  ('ENSG00000187815          ', 'ZFP69'),
#  ('ENSG00000162522          ', 'KIAA1522'),
#  ('ENSG00000162688          ', 'AGL'),
#  ('ENSG00000169641          ', 'LUZP1'),
#  ('ENSG00000164002          ', 'EXO5'),
#  ('ENSG00000004487          ', 'KDM1A'),
#  ('ENSG00000123473          ', 'STIL'),
#  ('ENSG00000137965          ', 'IFI44'),
#  ('ENSG00000117010          ', 'ZNF684'),
#  ('ENSG00000142733          ', 'MAP3K6'),
#  ('ENSG00000116497          ', 'S100PBP'),
#  ('ENSG00000134684          ', 'YARS1'),
#  ('ENSG00000251246          ', 'AL691442.2'),
#  ('ENSG00000143590          ', 'EFNA3'),
#  ('ENSG00000243364          ', 'EFNA4'),
#  ('ENSG00000142599          ', 'RERE'),
#  ('ENSG00000130762          ', 'ARHGEF16'),
#  ('ENSG00000265808          ', 'SEC22B'),
#  ('ENSG00000174827          ', 'PDZK1'),
#  ('ENSG00000179546          ', 'HTR1D'),
#  ('ENSG00000196171          ', 'OR6K2'),
#  ('ENSG00000117016          ', 'RIMS3'),
#  ('ENSG00000169242          ', 'EFNA1'),
#  ('ENSG00000203757          ', 'OR6K3'),
#  ('ENSG00000162571          ', 'TTLL10'),
#  ('ENSG00000024526          ', 'DEPDC1'),
#  ('ENSG00000143436          ', 'MRPL9'),
#  ('ENSG00000058799          ', 'YIPF1'),
#  ('ENSG00000197403          ', 'OR6N1'),
#  ('ENSG00000182134          ', 'TDRKH'),
#  ('ENSG00000180433          ', 'OR6K6'),
#  ('ENSG00000265491          ', 'RNF115'),
#  ('ENSG00000117281          ', 'CD160'),
#  ('ENSG00000186141          ', 'POLR3C'),
#  ('ENSG00000142748          ', 'FCN3'),
#  ('ENSG00000174950          ', 'CD164L2'),
#  ...]

# %% [markdown]
# Another clause is `UNION`, which can combine two subqueries, basically paste one of the subquery tables on top of another.

# %%
# %%sql
#     (SELECT * FROM gene WHERE gene_symbol = 'TP53')
#     UNION
#     (SELECT* FROM gene WHERE gene_symbol = 'FGFR2')
# Out:
#  * postgresql://postgres:***@localhost:5433/ensembl
# 2 rows affected.
# [('ENSG00000066468          ', -1, 121598458, 121478334, '10', 'FGFR2'),
#  ('ENSG00000141510          ', -1, 7687550, 7661779, '17', 'TP53')]

# %% [markdown]
# # Fix Me!
#
# Why does this UNION query not work?
#
# Modify the bottom subquery to work with the top subquery.

# %%
#fix the second SQL statement!
# %%sql
    (SELECT ensembl_gene_id, gene_symbol FROM gene WHERE gene_symbol = 'TP53')
    UNION
    (SELECT* FROM gene WHERE gene_symbol = 'FGFR2')

# %% [markdown]
# # What's Next?
#
# We'll learn some of the intricacies about Database Design and Normalization. Stay tuned!

# %% [markdown]
# # Acknowledgements
#
# This notebook was adapted from a tutorial by Christina Zheng.
